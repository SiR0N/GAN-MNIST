# %% [markdown]
# # GAN - MNIST EXAMPLE

# %% [markdown]
# In this notebook I will use GAN to generate handwritten digits from random noise. To train the model I use the MNIST dataset, the images size is 28x28 (784), in the range 0-255 (greyscale)
#
#
# The idea of GAN is to use two networks, the generative network generates candidates while the discriminative network evaluates them. They contest each other.

# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

tf.logging.set_verbosity(tf.logging.ERROR)

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# %%
plt.figure(figsize=(6, 3))
for i in range(18):
    plt.subplot(3, 6, i+1)
    plt.imshow(x_train[i], cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# Function to create the random noise

# %%
def make_random_samples(n_samples, sample_size):
    
    return np.random.normal(loc=0, scale=1, size=(n_samples, sample_size))

# %%
sample = make_random_samples(1, 100)
sample
# Out:
# array([[ 1.7399431 , -0.50846882, -0.83818449,  0.77345711, -0.47640266,
#          0.11445298, -0.91790651, -0.16422563,  0.99830916,  0.60581005,
#         -0.71450813, -1.35537506,  1.53782334,  0.89572892,  0.44000124,
#          1.05261126,  0.63459736,  0.03753486,  0.14414193,  0.68734338,
#          0.2170974 , -0.40900869,  0.48699261, -0.20571331, -1.39094543,
#          0.51019607,  0.52583387,  0.75767782, -0.75541196, -0.36659992,
#          0.15547718,  0.38323531, -0.31763489, -0.40071134,  0.62616409,
#         -1.37807959,  1.38810121, -1.39520977,  0.29936741, -0.29775437,
#         -0.31111561,  0.99853873,  0.59863869, -0.24730348, -0.69986503,
#          0.04179892,  0.33979317,  1.24992398, -0.34082492,  1.83418343,
#         -2.07602335, -2.48042429, -0.44081153, -0.09943688,  1.20195683,
#          1.96794533, -0.03932505,  0.42121165,  1.10859663,  0.90326493,
#          1.29508861, -1.93250136,  0.51941418,  1.20680692,  0.7653375 ,
#         -0.53481461, -0.16504235, -0.28919821,  2.41838758,  0.09122461,
#          1.07631711,  0.22468268, -0.95525475, -0.69560389,  1.19489454,
#         -0.00628062, -0.10880431,  0.81270954,  1.27059842,  1.01039808,
#         -0.63077937, -1.84373654, -0.95128961,  1.50466714,  0.17181492,
#          0.2548027 , -0.10979814,  1.39340111, -0.07777423, -0.15160202,
#         -1.95240187,  1.99638178,  0.31603405, -1.72307412,  0.26413639,
#          1.50550191, -0.64016451, -1.01120349, -0.45583429,  0.76508231]])

# %% [markdown]
# Processing the data,  in this case the range must be -1 to 1 as the generator uses a than activation function

# %%
def preprocess(x):    
    x = x.reshape(-1, 784) 
    x = np.float64(x)
    x = (x / 255 - 0.5) * 2
    x = np.clip(x, -1, 1)
    return x

def deprocess(x):
    x = (x / 2 + 1) * 255
    x = np.clip(x, 0, 255)
    x = np.uint8(x)
    x = x.reshape(28, 28)
    return x

# %%
X_train_real = preprocess(x_train)
X_test_real  = preprocess(x_test)

# %%
plt.figure(figsize=(6, 3))
for i in range(18):
    plt.subplot(3, 6, i+1)
    img = deprocess(X_train_real[i])
    plt.imshow(img, cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()

# %% [markdown]
# Labels are: 0 = FAKE and 1 = REAL

# %%
def make_labels(size):
    return np.ones([size, 1]), np.zeros([size, 1])

# %% [markdown]
# Activation Funtions, BIAS and Optimizer

# %%
def leaky_relu(net, name=None):
    return tf.maximum(0.01 * net, net, name=name)

def tanh(net, name=None):
    return tf.nn.tanh(net, name=None)

def sigmoid(net, name=None):
    return tf.math.sigmoid(net, name=None)

he_init = tf.contrib.layers.variance_scaling_initializer()

#Adam
def adamOptimizer(lr):

    decay_momentum = 0.875
    decay_scaling = 0.99898989898
    epsilon = 6.626e-4   #Planck constant: 6.626069934(89)×10−34
    optimizer = tf.train.AdamOptimizer(learning_rate=lr,
                                       beta1=decay_momentum,
                                       beta2=decay_scaling,
                                       epsilon=epsilon)
    return optimizer

# %% [markdown]
# # Build network

# %%
def createNNfromTopology(topology, activation):
    layers = []
    out = 0
    input = 0
    
    
    for i in range(1,len(topology)):
        input = topology[i-1]
        out = topology[i]
        if i == len(topology)-1:
           
            layers.append(tf.keras.layers.Dense(out, activation=activation,input_shape=(input,),kernel_initializer = he_init))
        else:
            
            layers.append(tf.keras.layers.Dense(out, activation=leaky_relu,input_shape=(input,),kernel_initializer = he_init))
        #print(layers[i-1].get_config())
    
    
    return layers

# %%
def CreateGan(gen_topology, dis_topology, gl,dl):
    

    gen_model = tf.keras.Sequential(createNNfromTopology( gen_topology, tanh),name="gen")
    gen_model.summary()

    
    
    #discriminator
    dis_model = tf.keras.Sequential(createNNfromTopology(dis_topology, sigmoid), name="dis")
    dis_model.summary()
   
    #gan
    gan = tf.keras.Sequential([
    gen_model,
    dis_model], name="gan")

    gan.summary()
     
    
    dis_model.compile(optimizer=adamOptimizer(dl), loss='binary_crossentropy')
    gan.compile(optimizer=adamOptimizer(gl), loss='binary_crossentropy')
    
    return gan, gen_model, dis_model

# %% [markdown]
# In some cases it is not needed to train the discriminator

# %%
def make_trainable(model, trainable):
    
    for layer in model.layers:
        layer.trainable = trainable

# %% [markdown]
# # Hyperparameters

# %%
sample_size     = 100     
image_size      = 784
g_lr            = 0.0001  # Generator learning rate
d_lr            = 0.001   # Discriminator learning rate
epochs          = 150
batch_size      = 64      # train batch size
eval_size       = 32      # evaluate size
smooth          = 0.1

g_topology = [sample_size, 128, 256,   image_size] 
d_topology = [image_size,256, 128, 64,   1]

# %% [markdown]
# # Training

# %%
# labels for the batch size and the test size
y_train_real, y_train_fake = make_labels(batch_size)
y_eval_real,  y_eval_fake  = make_labels(eval_size)




# create a GAN, a generator and a discriminator

gan, gen_model, dis_model = CreateGan(g_topology, d_topology,g_lr,d_lr)

losses = []
samples = []

for e in range(epochs):
    for i in range(len(X_train_real)//batch_size):
        # real MNIST digit images
        X_batch_real = X_train_real[i*batch_size:(i+1)*batch_size]
        
        # latent samples and the generated digit images
        latent_samples = make_random_samples(batch_size, sample_size)
        X_batch_fake = gen_model.predict_on_batch(latent_samples)
        
        
        
        # train the discriminator to detect real and fake images
        make_trainable(dis_model, True)        
        dis_model.train_on_batch(X_batch_real, y_train_real * (1 - smooth))
        dis_model.train_on_batch(X_batch_fake, y_train_fake)

        # train the generator via GAN
        make_trainable(dis_model, False)     
        gan.train_on_batch(latent_samples, y_train_real)
    
    # evaluate
    X_eval_real = X_test_real[np.random.choice(len(X_test_real), eval_size, replace=False)]
    
    latent_samples = make_random_samples(eval_size, sample_size)
    X_eval_fake = gen_model.predict_on_batch(latent_samples)
    
    samples.append(X_eval_fake)

    d_loss  = dis_model.test_on_batch(X_eval_real, y_eval_real)
    d_loss += dis_model.test_on_batch(X_eval_fake, y_eval_fake)
    g_loss  = gan.test_on_batch(latent_samples, y_eval_real) # we want the fake to be realistic!
    
    losses.append((d_loss, g_loss))
    
    print("Epoch: {:>3}/{} Discriminator Loss: {:>6.4f} Generator Loss: {:>6.4f}".format(
        e+1, epochs, d_loss, g_loss))
# Out:
# Model: "gen"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_8 (Dense)              (None, 128)               12928
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_10 (Dense)             (None, 784)               201488
# =================================================================
# Total params: 247,440
# Trainable params: 247,440
# Non-trainable params: 0
# _________________________________________________________________
# Model: "dis"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_11 (Dense)             (None, 256)               200960
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_13 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 242,177
# Trainable params: 242,177
# Non-trainable params: 0
# _________________________________________________________________
# Model: "gan"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gen (Sequential)             (None, 784)               247440
# _________________________________________________________________
# dis (Sequential)             (None, 1)                 242177
# =================================================================
# Total params: 489,617
# Trainable params: 489,617
# Non-trainable params: 0
# _________________________________________________________________
# Epoch:   1/150 Discriminator Loss: 0.3360 Generator Loss: 2.1236
# Epoch:   2/150 Discriminator Loss: 0.2251 Generator Loss: 2.2717
# Epoch:   3/150 Discriminator Loss: 0.5598 Generator Loss: 1.6483
# Epoch:   4/150 Discriminator Loss: 0.3217 Generator Loss: 2.4826
# Epoch:   5/150 Discriminator Loss: 0.3774 Generator Loss: 3.1038
# Epoch:   6/150 Discriminator Loss: 0.5154 Generator Loss: 1.7991
# Epoch:   7/150 Discriminator Loss: 0.5034 Generator Loss: 2.8256
# Epoch:   8/150 Discriminator Loss: 0.3574 Generator Loss: 3.0811
# Epoch:   9/150 Discriminator Loss: 0.4327 Generator Loss: 4.4075
# Epoch:  10/150 Discriminator Loss: 0.7010 Generator Loss: 2.4629
# Epoch:  11/150 Discriminator Loss: 0.6144 Generator Loss: 1.8537
# Epoch:  12/150 Discriminator Loss: 0.5218 Generator Loss: 2.8428
# Epoch:  13/150 Discriminator Loss: 0.7818 Generator Loss: 1.9476
# Epoch:  14/150 Discriminator Loss: 0.4926 Generator Loss: 2.7813
# Epoch:  15/150 Discriminator Loss: 0.3634 Generator Loss: 3.7962
# Epoch:  16/150 Discriminator Loss: 0.6707 Generator Loss: 2.5706
# Epoch:  17/150 Discriminator Loss: 0.6926 Generator Loss: 4.0714
# Epoch:  18/150 Discriminator Loss: 0.5034 Generator Loss: 2.7220
# Epoch:  19/150 Discriminator Loss: 0.6642 Generator Loss: 2.5341
# Epoch:  20/150 Discriminator Loss: 0.3790 Generator Loss: 3.1286
# Epoch:  21/150 Discriminator Loss: 0.5196 Generator Loss: 3.9607
# Epoch:  22/150 Discriminator Loss: 0.8228 Generator Loss: 3.2244
# Epoch:  23/150 Discriminator Loss: 0.4304 Generator Loss: 3.6482
# Epoch:  24/150 Discriminator Loss: 0.6980 Generator Loss: 2.7479
# Epoch:  25/150 Discriminator Loss: 0.4215 Generator Loss: 2.7059
# Epoch:  26/150 Discriminator Loss: 0.7770 Generator Loss: 3.5434
# Epoch:  27/150 Discriminator Loss: 0.7937 Generator Loss: 2.9521
# Epoch:  28/150 Discriminator Loss: 1.0788 Generator Loss: 3.6263
# Epoch:  29/150 Discriminator Loss: 0.9345 Generator Loss: 3.1868
# Epoch:  30/150 Discriminator Loss: 0.5840 Generator Loss: 2.8781
# Epoch:  31/150 Discriminator Loss: 0.4418 Generator Loss: 3.3269
# Epoch:  32/150 Discriminator Loss: 0.7485 Generator Loss: 2.0306
# Epoch:  33/150 Discriminator Loss: 1.2589 Generator Loss: 2.6993
# Epoch:  34/150 Discriminator Loss: 1.2158 Generator Loss: 3.1005
# Epoch:  35/150 Discriminator Loss: 0.8686 Generator Loss: 2.7260
# Epoch:  36/150 Discriminator Loss: 0.8761 Generator Loss: 3.1814
# Epoch:  37/150 Discriminator Loss: 0.4402 Generator Loss: 2.6499
# Epoch:  38/150 Discriminator Loss: 0.4987 Generator Loss: 2.6619
# Epoch:  39/150 Discriminator Loss: 0.6231 Generator Loss: 2.1697
# Epoch:  40/150 Discriminator Loss: 0.5585 Generator Loss: 2.5811
# Epoch:  41/150 Discriminator Loss: 0.6699 Generator Loss: 2.2926
# Epoch:  42/150 Discriminator Loss: 0.6475 Generator Loss: 2.1075
# Epoch:  43/150 Discriminator Loss: 1.0455 Generator Loss: 2.0852
# Epoch:  44/150 Discriminator Loss: 0.8082 Generator Loss: 1.7236
# Epoch:  45/150 Discriminator Loss: 0.5948 Generator Loss: 2.5628
# Epoch:  46/150 Discriminator Loss: 0.9654 Generator Loss: 1.6075
# Epoch:  47/150 Discriminator Loss: 0.7870 Generator Loss: 2.5456
# Epoch:  48/150 Discriminator Loss: 0.7460 Generator Loss: 2.6717
# Epoch:  49/150 Discriminator Loss: 0.8507 Generator Loss: 3.5342
# Epoch:  50/150 Discriminator Loss: 0.7582 Generator Loss: 2.1676
# Epoch:  51/150 Discriminator Loss: 1.1681 Generator Loss: 1.9186
# Epoch:  52/150 Discriminator Loss: 1.1164 Generator Loss: 3.2604
# Epoch:  53/150 Discriminator Loss: 0.7485 Generator Loss: 2.5045
# Epoch:  54/150 Discriminator Loss: 0.7315 Generator Loss: 1.8485
# Epoch:  55/150 Discriminator Loss: 0.8739 Generator Loss: 1.8956
# Epoch:  56/150 Discriminator Loss: 0.6416 Generator Loss: 2.1454
# Epoch:  57/150 Discriminator Loss: 1.2807 Generator Loss: 3.4846
# Epoch:  58/150 Discriminator Loss: 1.6241 Generator Loss: 4.1213
# Epoch:  59/150 Discriminator Loss: 1.4229 Generator Loss: 3.6801
# Epoch:  60/150 Discriminator Loss: 0.9162 Generator Loss: 2.3930
# Epoch:  61/150 Discriminator Loss: 1.3057 Generator Loss: 2.3653
# Epoch:  62/150 Discriminator Loss: 1.2613 Generator Loss: 3.2819
# Epoch:  63/150 Discriminator Loss: 1.5275 Generator Loss: 2.8007
# Epoch:  64/150 Discriminator Loss: 1.1551 Generator Loss: 2.6697
# Epoch:  65/150 Discriminator Loss: 1.2054 Generator Loss: 2.7146
# Epoch:  66/150 Discriminator Loss: 1.2652 Generator Loss: 2.5373
# Epoch:  67/150 Discriminator Loss: 1.3335 Generator Loss: 2.9944
# Epoch:  68/150 Discriminator Loss: 1.2522 Generator Loss: 2.6499
# Epoch:  69/150 Discriminator Loss: 0.9194 Generator Loss: 2.3755
# Epoch:  70/150 Discriminator Loss: 1.3823 Generator Loss: 3.0507
# Epoch:  71/150 Discriminator Loss: 1.2994 Generator Loss: 2.5361
# Epoch:  72/150 Discriminator Loss: 1.0223 Generator Loss: 2.1387
# Epoch:  73/150 Discriminator Loss: 1.0754 Generator Loss: 2.0043
# Epoch:  74/150 Discriminator Loss: 1.1174 Generator Loss: 2.7508
# Epoch:  75/150 Discriminator Loss: 1.4456 Generator Loss: 2.8631
# Epoch:  76/150 Discriminator Loss: 1.1636 Generator Loss: 2.4621
# Epoch:  77/150 Discriminator Loss: 0.9582 Generator Loss: 1.9598
# Epoch:  78/150 Discriminator Loss: 1.2393 Generator Loss: 1.7495
# Epoch:  79/150 Discriminator Loss: 1.0060 Generator Loss: 1.7826
# Epoch:  80/150 Discriminator Loss: 1.4755 Generator Loss: 1.5594
# Epoch:  81/150 Discriminator Loss: 0.9169 Generator Loss: 2.7758
# Epoch:  82/150 Discriminator Loss: 1.1893 Generator Loss: 2.3846
# Epoch:  83/150 Discriminator Loss: 1.1174 Generator Loss: 2.0903
# Epoch:  84/150 Discriminator Loss: 1.3541 Generator Loss: 2.4376
# Epoch:  85/150 Discriminator Loss: 1.0777 Generator Loss: 2.5211
# Epoch:  86/150 Discriminator Loss: 1.0852 Generator Loss: 2.5920
# Epoch:  87/150 Discriminator Loss: 1.1637 Generator Loss: 2.2910
# Epoch:  88/150 Discriminator Loss: 1.4030 Generator Loss: 2.9124
# Epoch:  89/150 Discriminator Loss: 1.2417 Generator Loss: 2.2853
# Epoch:  90/150 Discriminator Loss: 1.3728 Generator Loss: 1.7772
# Epoch:  91/150 Discriminator Loss: 1.0906 Generator Loss: 2.3852
# Epoch:  92/150 Discriminator Loss: 1.3721 Generator Loss: 1.9598
# Epoch:  93/150 Discriminator Loss: 1.1912 Generator Loss: 2.2671
# Epoch:  94/150 Discriminator Loss: 1.6028 Generator Loss: 2.6518
# Epoch:  95/150 Discriminator Loss: 1.2299 Generator Loss: 2.0114
# Epoch:  96/150 Discriminator Loss: 1.3977 Generator Loss: 2.1202
# Epoch:  97/150 Discriminator Loss: 1.1125 Generator Loss: 2.3299
# Epoch:  98/150 Discriminator Loss: 1.2413 Generator Loss: 1.7822
# Epoch:  99/150 Discriminator Loss: 1.2861 Generator Loss: 2.3830
# Epoch: 100/150 Discriminator Loss: 1.2279 Generator Loss: 1.8396
# Epoch: 101/150 Discriminator Loss: 1.0877 Generator Loss: 1.5855
# Epoch: 102/150 Discriminator Loss: 1.0597 Generator Loss: 1.5069
# Epoch: 103/150 Discriminator Loss: 1.0904 Generator Loss: 2.2267
# Epoch: 104/150 Discriminator Loss: 1.3047 Generator Loss: 1.5399
# Epoch: 105/150 Discriminator Loss: 0.8684 Generator Loss: 1.9324
# Epoch: 106/150 Discriminator Loss: 1.2601 Generator Loss: 1.7568
# Epoch: 107/150 Discriminator Loss: 0.9644 Generator Loss: 1.6547
# Epoch: 108/150 Discriminator Loss: 1.1766 Generator Loss: 1.8655
# Epoch: 109/150 Discriminator Loss: 1.0764 Generator Loss: 1.4047
# Epoch: 110/150 Discriminator Loss: 1.0865 Generator Loss: 1.5809
# Epoch: 111/150 Discriminator Loss: 1.1155 Generator Loss: 1.7222
# Epoch: 112/150 Discriminator Loss: 1.1589 Generator Loss: 1.5136
# Epoch: 113/150 Discriminator Loss: 1.2327 Generator Loss: 1.6184
# Epoch: 114/150 Discriminator Loss: 0.8678 Generator Loss: 1.6413
# Epoch: 115/150 Discriminator Loss: 1.0153 Generator Loss: 1.2648
# Epoch: 116/150 Discriminator Loss: 1.1235 Generator Loss: 1.6676
# Epoch: 117/150 Discriminator Loss: 1.0192 Generator Loss: 1.2075
# Epoch: 118/150 Discriminator Loss: 0.8180 Generator Loss: 1.4655
# Epoch: 119/150 Discriminator Loss: 1.0899 Generator Loss: 1.4640
# Epoch: 120/150 Discriminator Loss: 1.2637 Generator Loss: 1.3429
# Epoch: 121/150 Discriminator Loss: 1.3024 Generator Loss: 1.5633
# Epoch: 122/150 Discriminator Loss: 1.2037 Generator Loss: 1.5501
# Epoch: 123/150 Discriminator Loss: 1.0992 Generator Loss: 1.5075
# Epoch: 124/150 Discriminator Loss: 1.0174 Generator Loss: 1.6136
# Epoch: 125/150 Discriminator Loss: 1.3286 Generator Loss: 1.5524
# Epoch: 126/150 Discriminator Loss: 1.3969 Generator Loss: 2.0153
# Epoch: 127/150 Discriminator Loss: 1.0680 Generator Loss: 1.3518
# Epoch: 128/150 Discriminator Loss: 1.0170 Generator Loss: 1.5040
# Epoch: 129/150 Discriminator Loss: 0.9571 Generator Loss: 1.8165
# Epoch: 130/150 Discriminator Loss: 1.1273 Generator Loss: 1.5178
# Epoch: 131/150 Discriminator Loss: 1.2594 Generator Loss: 1.7900
# Epoch: 132/150 Discriminator Loss: 0.8291 Generator Loss: 1.5708
# Epoch: 133/150 Discriminator Loss: 1.1685 Generator Loss: 1.4948
# Epoch: 134/150 Discriminator Loss: 1.0560 Generator Loss: 2.1817
# Epoch: 135/150 Discriminator Loss: 1.0863 Generator Loss: 1.5334
# Epoch: 136/150 Discriminator Loss: 1.3034 Generator Loss: 1.5935
# Epoch: 137/150 Discriminator Loss: 1.2489 Generator Loss: 1.7062
# Epoch: 138/150 Discriminator Loss: 1.1712 Generator Loss: 1.6531
# Epoch: 139/150 Discriminator Loss: 1.2371 Generator Loss: 1.7340
# Epoch: 140/150 Discriminator Loss: 1.4637 Generator Loss: 1.7766
# Epoch: 141/150 Discriminator Loss: 1.3934 Generator Loss: 1.7971
# Epoch: 142/150 Discriminator Loss: 1.6003 Generator Loss: 1.4463
# Epoch: 143/150 Discriminator Loss: 1.4040 Generator Loss: 2.0424
# Epoch: 144/150 Discriminator Loss: 1.4427 Generator Loss: 1.9724
# Epoch: 145/150 Discriminator Loss: 1.0683 Generator Loss: 2.1562
# Epoch: 146/150 Discriminator Loss: 1.2533 Generator Loss: 1.6119
# Epoch: 147/150 Discriminator Loss: 1.2014 Generator Loss: 1.4582
# Epoch: 148/150 Discriminator Loss: 1.1303 Generator Loss: 1.4412
# Epoch: 149/150 Discriminator Loss: 1.1806 Generator Loss: 1.7279
# Epoch: 150/150 Discriminator Loss: 1.5017 Generator Loss: 1.6573

# %% [markdown]
# # Training analysis

# %% [markdown]
# Images generated by the Generator at the last epoch

# %%
def view_samples(epoch, samples):
    fig, axes = plt.subplots( nrows=3, ncols=6, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

_ = view_samples(-1, samples)

# %% [markdown]
# Images generaded by the Generator Network every 10 epochs

# %%
rows, cols = 10, 6
fig, axes = plt.subplots(figsize=(7,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

for sample, ax_row in zip(samples[::int(len(samples)/rows)], axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %% [markdown]
# # Loss

# %%
losses = np.array(losses)

fig, ax = plt.subplots()
plt.plot(losses.T[0], label='Discriminator')
plt.plot(losses.T[1], label='Generator')
plt.title("Training Losses")
plt.legend()
plt.show()

# %% [markdown]
# # Generator model test

# %%
latent_samples = make_random_samples(18, sample_size)
generated_digits = gen_model.predict(latent_samples)

plt.figure(figsize=(10, 8))
for i in range(18):
    img = deprocess(generated_digits[i])
    plt.subplot(3, 6, i+1)
    plt.imshow(img, cmap='gray')
    plt.xticks([])
    plt.yticks([])
plt.tight_layout()
plt.show()
